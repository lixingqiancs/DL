# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_file, show

# %%
pd.set_option('precision', 10)

# %%
p = figure(title="simple line example", x_axis_label='s_time', y_axis_label='ratio')

# %%
p.line(s_time, ratio, legend="Temp.", line_width=2)

# %%
show(p)

# %%
plt.plot(x,y)

# %%
plt.plot(x,z,color='red',linewidth=1,linestyle='--')

# %%
df = pd.read_csv("2020_0428.1AM_2021April02.15PM - 2020_0428.1AM_2021April02.15PM.csv")

# %%
print df

# %%
x_time=df["data__hour"]
# y_btc=df['data__priceUsd']
# marketcap_btc=df['data__priceUsd']*df['data__circulatingSupply']

# %%
x_time
# Out:
# 0       2020-04-28T01:00:00.000Z
# 1       2020-04-28T02:00:00.000Z
# 2       2020-04-28T03:00:00.000Z
# 3       2020-04-28T04:00:00.000Z
# 4       2020-04-28T05:00:00.000Z
# 5       2020-04-28T06:00:00.000Z
# 6       2020-04-28T07:00:00.000Z
# 7       2020-04-28T08:00:00.000Z
# 8       2020-04-28T09:00:00.000Z
# 9       2020-04-28T10:00:00.000Z
# 10      2020-04-28T11:00:00.000Z
# 11      2020-04-28T12:00:00.000Z
# 12      2020-04-28T13:00:00.000Z
# 13      2020-04-28T14:00:00.000Z
# 14      2020-04-28T15:00:00.000Z
# 15      2020-04-28T16:00:00.000Z
# 16      2020-04-28T17:00:00.000Z
# 17      2020-04-28T18:00:00.000Z
# 18      2020-04-28T19:00:00.000Z
# 19      2020-04-28T20:00:00.000Z
# 20      2020-04-28T21:00:00.000Z
# 21      2020-04-28T22:00:00.000Z
# 22      2020-04-28T23:00:00.000Z
# 23      2020-04-29T00:00:00.000Z
# 24      2020-04-29T01:00:00.000Z
# 25      2020-04-29T02:00:00.000Z
# 26      2020-04-29T03:00:00.000Z
# 27      2020-04-29T04:00:00.000Z
# ...

# %%
plt.plot(x_btc,marketcap_btc)

# %%
print(marketcap_btc)

# %%
dfeth = pd.read_csv("ETH_April28_1AM_April02_15PM.csv")

# %%
x_eth=df["time"]

# %%
print("x_eth")

# %%
print(x_eth)

# %%
twoy_btc=df["data__priceUsd"]

# %%
twoy_eth=df["priceUsd"]

# %%
marketcap_eth=df['priceUsd']*df['circulatingSupply']

# %%
ratio = df['data__priceUsd']*df['data__circulatingSupply']/df['priceUsd']/df['circulatingSupply']

# %%
print(twoy_eth)
# Out:
# 0        195.1265307
# 1        193.9936823
# 2        194.3683161
# 3        194.8090749
# 4        193.8067892
# 5        194.9141762
# 6        195.8094492
# 7        195.4334145
# 8        194.2857101
# 9        195.9795288
# 10       196.8711629
# 11       196.3990908
# 12       197.3660951
# 13       196.4164889
# 14       195.1535755
# 15       195.8182195
# 16       195.8046304
# 17       196.0955942
# 18       196.7465344
# 19       195.8266474
# 20       196.6999634
# 21       196.8168278
# 22       198.4660234
# 23       196.9685212
# 24       196.9018604
# 25       197.6669060
# 26       197.9376430
# 27       198.2762795
# 28       198.8281949
# 29       199.5598153
#             ...
# 8121    1931.0581010
# 8122    1922.4722390
# 8123    1924.9711920
# 8124    1937.9083080
# 8125    1932.9929040
# 8126    1947.1249600
# 8127    1949.1429060
# 8128    1941.1801240
# 8129    1967.8214370
# 8130    1976.6278260
# 8131    1973.8617760
# 8132    1966.2271750
# ...

# %%
ratio_btc_eth = marketcap_btc/marketcap_btc

# %%
print(ratio_btc_eth)

# %%
s_time = pd.to_datetime(df["data__hour"]).dt.tz_localize(None)

# %%
s_time1 = pd.to_datetime(df["data__hour"]).dt.tz_localize(None)

# %%
s_time1

# %%
s_time

# %%
plt.plot(s_time,ratio)

# %%
plt.plot(s_time,twoy_eth)

# %%
twoy_eth

# %%
p = figure(title="simple line example", x_axis_label='s_time', y_axis_label='ratio')

# %%
p.line(s_time, c, legend="Temp.", line_width=2)

# %%
show(p)

# %%
ax = df.plot(
    secondary_y=['gmv'],
    x_compat=True,
    grid=True)
 
ax.set_title("pv-gmv")
ax.set_ylabel('pv')
ax.grid(linestyle="--", alpha=0.3)
 
ax.right_ax.set_ylabel('gmv')

# %%
print (twoy_btc)

# %%
plt.plot(x_time, twoy_eth)

# %%
import matplotlib.pyplot as plt
import numpy as np
 
# x = np.arange(0,6)
# y1= [30481,12583,51,9,2,2]
# y2= [0.0065,0.016,0.039,0,0,0]
 
fig,ax1 = plt.subplots()
ax2 = ax1.twinx()           # 做镜像处理
#ax3 = ax2.twinx()
ax1.plot(s_time,ratio,'g-')
ax2.plot(s_time,twoy_btc,'b--')
ax3.plot(s_time,twoy_eth,'c--')


 
ax1.set_xlabel('1 hour 1 AM, April 28,2020 - 15 PM April 02, 2021')    #设置x轴标题
ax1.set_ylabel('BTC/ETH Market Cap',color = 'g')   #设置Y1轴标题
ax2.set_ylabel('BTC Price Per Hour',color = 'b')   #设置Y2轴标题
#ax3.set_ylabel('ETH Price Per Hour',color = 'c')
# Out:
# Text(0,0.5,'BTC Price Per Hour')

# %%
twoy_eth

# %%
fig,ax1 = plt.subplots()
#ax2 = ax1.twinx()           # 做镜像处理
ax3 = ax1.twinx()
ax1.plot(s_time,ratio,'g-')
#ax2.plot(s_time,twoy_btc,'b--')
ax3.plot(s_time,twoy_eth,'c--')


ax1.set_xlabel('1 hour 1 AM, April 28,2020 - 15 PM April 02, 2021')    #设置x轴标题
ax1.set_ylabel('BTC/ETH Market Cap',color = 'g')   #设置Y1轴标题
#ax2.set_ylabel('BTC Price Per Hour',color = 'b')   #设置Y2轴标题
ax3.set_ylabel('ETH Price Per Hour',color = 'c')
# Out:
# Text(0,0.5,'ETH Price Per Hour')

# %%
import matplotlib.pyplot as plt
import numpy as np
 
# x = np.arange(0,6)
# y1= [30481,12583,51,9,2,2]
# y2= [0.0065,0.016,0.039,0,0,0]
 
fig,ax1 = plt.subplots()
ax2 = ax1.twinx()           # 做镜像处理
#ax3 = ax1.twinx()
#ax1.plot(s_time,ratio,'g-')
ax1.plot(s_time,twoy_btc,'b--')
ax2.plot(s_time,twoy_eth,'c--')


 
ax1.set_xlabel('1 hour 1 AM, April 28,2020 - 15 PM April 02, 2021')    #设置x轴标题
ax1.set_ylabel('BTC/ETH Market Cap',color = 'g')   #设置Y1轴标题
ax2.set_ylabel('BTC Price Per Hour',color = 'b')   #设置Y2轴标题
#ax3.set_ylabel('ETH Price Per Hour',color = 'c')
# Out:
# Text(0,0.5,'BTC Price Per Hour')
